# %% [markdown]
# # Seminar Notebook 1.4: Word Clouds and Weighting
#
# **LSE MY459: Computational Text Analysis and Large Language Models** (WT 2026)
#
# **Ryan Hübert**
#
# This notebook covers word clouds and DFM weighting.

# %% [markdown]
# ## Directory management
#
# We begin with some directory management to specify the file path to the folder on your computer where you wish to store data for this notebook.

# %%
import os
sdir = os.path.join(os.path.expanduser("~"), "LSE-MY459-WT26", "SeminarWeek02") # or whatever path you want
if not os.path.exists(sdir):
    os.mkdir(sdir)

# %% [markdown]
# ### Loading the DFM
#
# We need to load the DFM we created in the last notebook. We start by reading the sparse array object we saved as an `.npz` file:

# %%
from scipy import sparse

sparse_dfm_file = os.path.join(sdir, 'tweet-dfm-sparse.npz')
if os.path.exists(sparse_dfm_file):
    dfm_sparse = sparse.load_npz(sparse_dfm_file)
else:
    raise Exception

print(dfm_sparse)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 50274 stored elements and shape (3866, 5949)>
#   Coords	Values
#   (0, 96)	1.0
#   (0, 151)	1.0
#   (0, 883)	1.0
#   (0, 1200)	1.0
#   (0, 2533)	1.0
#   (0, 3470)	1.0
#   (0, 3544)	1.0
#   (0, 4404)	1.0
#   (0, 5424)	1.0
#   (0, 5876)	1.0
#   (0, 5881)	1.0
#   (1, 96)	1.0
#   (1, 209)	1.0
#   (1, 381)	1.0
#   (1, 660)	1.0
#   (1, 881)	1.0
#   (1, 1130)	1.0
#   (1, 2943)	1.0
#   (1, 3881)	1.0
#   (1, 4732)	1.0
#   (2, 590)	1.0
#   (2, 595)	1.0
#   (2, 881)	1.0
#   (2, 1200)	1.0
#   (2, 2533)	1.0
#   :	:
#   (3864, 2922)	1.0
#   (3864, 3570)	1.0
#   (3864, 3833)	1.0
#   (3864, 3880)	1.0
#   (3864, 4236)	1.0
#   (3864, 4940)	1.0
#   (3864, 4941)	1.0
#   (3864, 5422)	1.0
#   (3864, 5436)	1.0
#   (3864, 5764)	1.0
#   (3864, 5925)	1.0
#   (3865, 261)	1.0
#   (3865, 746)	1.0
#   (3865, 1226)	1.0
#   (3865, 1681)	1.0
#   (3865, 1802)	1.0
#   (3865, 3691)	1.0
#   (3865, 3752)	1.0
#   (3865, 4153)	1.0
#   (3865, 4470)	1.0
#   (3865, 4514)	1.0
#   (3865, 4641)	1.0
#   (3865, 4985)	1.0
#   (3865, 5315)	1.0
#   (3865, 5882)	1.0

# %% [markdown]
# Next, let's load the list of features (the vocabulary), which remember is not included with the sparse array data:

# %%
features_file = os.path.join(sdir, 'tweet-dfm-features.txt')
vocabulary = open(features_file, mode = "r").read().split("\n")
print(vocabulary)
# Out:
# ['#afghanistan', '#afghanstrategy', '#ahca', '#alconv2017', '#amazonwashingtonpost', '#america', '#americafirst', '#americafirst🇺🇸#unga', '#americanheroes', '#anthem', '#apec', '#apec2017', '#armedforcesday', '#armynavygame', '#asean50', '#aseansummit', '#autismawarenessday', '#az08', '#balticsummit', '#bastilleday', '#bombers', '#breakingnews', '#brussels', '#buildthewall', '#buyamericanhireamerican', '#bye-bye', '#cajunnavy', '#canada150', '#cashinin', '#ceotownhall', '#cg227', '#cgacommencement17', '#chagsameach', '#changethelaws', '#charliegard', '#charlot', '#charlottesville', '#columbusday', '#confirmgina', '#confirmgorsuch', '#congratspeggy', '#congressionalbaseballgame', '#congressionalgoldmedal', '#cpac2018', '#crookedhillary', '#davos2018', '#dday', '#democrat', '#democratshutdown', '#dobbs', '#dod', '#dow', '#dow23k', '#dow24k', '#dprk', '#draintheswam', '#draintheswamp', '#dts', '#earnhistory', '#endingwaroncoal', '#energyweek', '#entrepreneurs', '#faithandfreedom', '#fake', '#fakenews', '#falconheavy', '#family', '#familytime', '#fema', '#fieldday', '#fighttonight', '#fire', '#firstrespondersday', '#flagday', '#flashbackfriday', '#florida', '#fnn', '#fosta', '#fraudnewscnn', '#g20summit', '#g7', '#g7charlevoix', '#g7summit', '#g7taormina', '#ga06', '#ges2017', '#givingtuesday', '#godblesstheusa', '#goteamusa', '#government', '#halloween2017', '#hannity', '#hannityat9', '#hanukkah', '#happyhanukkah', '#happyindependenceday', '#happynewyear', '#happythanksgiving', '#harvey', '#healthcarebill', '#heroes', '#holocaustremembranceday', '#honorthem', '#houstonstrong', '#hurric', '#hurricaineirma', '#hurricaneharvey', '#hurricaneirma', '#hurricanejose', '#hurricanemaria', '#hurricanenate', '#icymi', '#icymi🇺🇸🇮🇱joint', '#inauguration', '#inauguration2017', '#inaugurationday', '#infrastructureinamerica', '#infrastructureweek', '#innovation', '#interdictact', '#internationalwomensday', '#iranprotests', '#irma', "#irma's", '#isis', '#itsa', '#japan', '#jfkfiles', '#jiatfsouth', '#jobsreport', '#jointaddress', '#jointsession', '#journalismisdead', '#july4', '#kateslaw', '#keystonepipeline', '#laborday', '#lambthesham', '#lasvegasstrong', '#laurel', '#lawenforcementappreciationday', '#leadright', '#leos', '#lesm', '#letsmakepeace', '#lightitupblue', '#liub', '#lovesaveslives', '#ma', '#madeinamerica', '#madeintheusa', '#maga', '#makeamericagreatagain', '#marchforlife', '#marineone', '#medalofhonor', '#medalofhonorday', '#memorialday', '#mlk50', '#mothersday', '#ms13', '#msm', '#nabtu2017', '#nasdaq', '#nationalagday', '#nationalagricultureday', '#nationalassembly', '#nationalchampions', '#nationaldayofprayer', '#nationalfarmersday', '#nationalpoliceweek', '#nationalprayerbreakfast', '#nationalteachersday', '#nato', '#natomeeting', '#ncaachampions🏆photos', '#ndsen', '#neveragain', '#neverforget', '#neverforget911', '#nevertrumpers', '#newyear', '#nfib75', '#nfl', '#noko', '#northkorea', '#nosanctuaryforcriminalsact', '#nycstrong', '#nytimes', '#obama', '#obamacare', '#obamaday', '#ocarenightmare', '#olympics', '#oneamericaappeal', '#opioidcrisis', '#opioidepidemic', '#orlandounitedday', '#ottowarmbier', '#passthebill', '#peaceofficersmemorialday', '#pearlharbor', '#pearlharborremembranceday', '#periscope', '#phoenixrally', '#photosfromthefield', '#planahead', '#police', '#policeweek', '#potus', '#potus7', '#potusabroad', '#potusinasia', '#potusinpoland', '#prayfortexas', '#prisonreform', '#prstrong', '#puertorico', '#puertorico🇵🇷with', '#pulsenightclub', '#purpleheartday💜i', '#raiseact', '#readthebill', '#realpresident', '#repealandreplace', '#repealobamacare', '#righttotry', '#riyadh', '#riyadhsummit', '#rolltide', '#s2155', '#s544', '#saudiaarabia', '#saveamericanlives', '#sbagala', '#schoolchoice', '#scotus', '#semperfi', '#sesta', '#shopsmall', '#singaporesummit', '#situationroom', '#smallbiz', '#smallbusinesssaturday', '#soldierridedc', '#soldiers', '#sotu', '#southernbaptist', '#spygate', '#standforourant', '#standforouran ...

# %% [markdown]
# Finally, we'll load the corpus that we saved, which contains the date and time of each tweet, which we may need to identify tweets in our DFM.

# %%
import pandas as pd

corpus_file = os.path.join(sdir, "tweet-corpus.csv")
corpus = pd.read_csv(corpus_file)
corpus["datetime"].head()
corpus["datetime"] = pd.to_datetime(corpus["datetime"]).dt.tz_convert("US/Eastern") # Convert to US Eastern time

# %% [markdown]
# ## Top features
#
# Let's calculate the top features of our DFM. Begin by summing across the rows of the DFM:

# %%
top_features = dfm_sparse.sum(axis = 0).A1
top_features
# Out:
# array([1., 1., 1., ..., 1., 4., 1.], shape=(5949,))

# %% [markdown]
# This tells us that the first three features appears 1 time in the corpus, the second to last feature appears 4 times, etc. We're looking at the sums across the rows of the DFM, but what are these features? That is, what column names correspond to each of these? Let's reformat to a nicer looking table using the list of features we read as the `vocabulary` object:

# %%
top_features = pd.Series(top_features, index=vocabulary)
top_features
# Out:
# #afghanistan             1.0
# #afghanstrategy          1.0
# #ahca                    1.0
# #alconv2017              2.0
# #amazonwashingtonpost    1.0
#                         ...
# zito                     1.0
# zone                     5.0
# zoo                      1.0
# zte                      4.0
# zuker                    1.0
# Length: 5949, dtype: float64

# %% [markdown]
# Finally, let's do a little clean up: reformat the counts as integers and arrange in descending order.

# %%
top_features = top_features.astype(int)
top_features = top_features.sort_values(ascending=False)
top_features[0:20]
# Out:
# great       831
# rt          419
# peopl       390
# countri     323
# news        306
# job         293
# thank       291
# presid      275
# tax         271
# today       270
# democrat    266
# big         259
# america     258
# year        256
# fake        254
# state       248
# get         245
# american    242
# u.          239
# work        237
# dtype: int64

# %% [markdown]
# ## Word clouds
#
# Word clouds are the standard way to visualise the top features in a DFM in a plot. To make a word cloud for this DFM, we can use the convenient `wordcloud` module along with one of the most standard plotting modules used in Python, `matplotlib`.

# %%
import wordcloud
import matplotlib.pyplot as plt

# %%
# Initialise the wordcloud object as `wc`
wc = wordcloud.WordCloud(width=800,
                         height=400,
                         background_color="white",
                         relative_scaling = 1,
                         max_words=200, 
                         random_state=42)

# Feed in the data from our `top_features` object
wc = wc.generate_from_frequencies(top_features)

# Don't use the default colours, and make blue
wc = wc.recolor(color_func=lambda *args, **kwargs: (51,51,255))

# %% [markdown]
# Now, we can use plotting tools from `matplotlib`.

# %%
plt.figure(figsize=(8, 4))
plt.imshow(wc)
plt.axis("off")
plt.subplots_adjust(left=0, right=1, top=1, bottom=0)
plt.show()

# %% [markdown]
# You can also save this word cloud to disk.

# %%
wc.to_file(os.path.join(sdir, "wordcloud.png"))

# %% [markdown]
# ## Weight DFMs
#
# The DFM we've been working with so far has been mostly "unweighted." Each cell contains the raw count of a particular feature (i.e., a processed token) in a particular document. However, we did actually do _some_ weighting during preprocessing when we removed stop words and other "non-word" tokens. In effect, we set the weights of each of those tokens to zero.
#
# Weighting DFMs can be useful because very commonly used words often have high frequencies in a DFM, but are not very informative. In those cases, you may wish to weight those words down by applying a penalty to their counts in the DFM. This is the rationale for removing stop words. The stop word "the" is useful for making English language text read more smoothly, but it rarely contains substantive information about what the author is intending to convey. On the opposite end of the spectrum, you may have words that are used very infrequently (e.g., one time), and thus do not convey a lot of information in an entire corpus of documents. In many text analysis contexts, you may wish to find a "sweet spot" where you weight words more heavily when they are used a lot frequent but concentrated in a relatively smaller number of documents.
#
# Here, we will cover two approaches to weighting that capture some of these ideas: "simple" weighting where we remove tokens that are not used much, and tf-idf weighting where we don't remove tokens, but rather boost or reduce the values in each cell of a DFM based on the usage patterns of tokens in the DFM.

# %% [markdown]
# ### Trimming a DFM based on frequency
#
# There are some words that appear in a corpus very infrequently, and thus contribute very little to an analysis of word usage. For example, the word "gentlemen" is used one time in one document in the (preprocessed) Trump tweet corpus.

# %%
top_features[top_features.index == "gentlemen"]
# Out:
# gentlemen    1
# dtype: int64

# %% [markdown]
# Including tokens like this in a DFM blows up the size of the DFM (more columns) and makes the DFM more sparse. This, in turn, can make statistical estimates more unstable and unreliable. In the next code chunk, we will "trim" our DFM by removing words that have low total term frequencies (TTFs, i.e., do not appear very many times overall), and that have low document frequencies (DFs, i.e., do not appear in many documents). By dropping them, we are effectively weighting them by zero.

# %%
# Calculate the document frequency for each feature
docf = (dfm_sparse > 0).sum(axis=0).A1
docf
# Out:
# array([1, 1, 1, ..., 1, 4, 1], shape=(5949,))

# %%
# Calculate the total term frequency for each feature
ttf = dfm_sparse.sum(axis=0).A1
ttf
# Out:
# array([1., 1., 1., ..., 1., 4., 1.], shape=(5949,))

# %% [markdown]
# If you want to preview the DF and the TTF for each feature in an easier-to-read format, you can use:

# %%
feature_ttf_df = pd.DataFrame({"docf": docf, "ttf": ttf}, index=vocabulary).astype(int)
feature_ttf_df
# Out:
#                        docf  ttf
# #afghanistan              1    1
# #afghanstrategy           1    1
# #ahca                     1    1
# #alconv2017               2    2
# #amazonwashingtonpost     1    1
# ...                     ...  ...
# zito                      1    1
# zone                      4    5
# zoo                       1    1
# zte                       4    4
# zuker                     1    1
#
# [5949 rows x 2 columns]

# %% [markdown]
# Now, let's trim the DFM. We need to make a choice about how aggressively to do it. Let's try two options and see how much of a difference it makes. First, let's remove all features that appear only one time in the entire corpus. This means at we want to keep any feature that has a minimum total term frequency of 2.

# %%
import numpy as np

min_ttf = 2

cols_keep = np.where(ttf >= min_ttf)[0]
cols_keep
# Out:
# array([   3,    5,    6, ..., 5942, 5945, 5947], shape=(3230,))

# %% [markdown]
# Here, we can see that if we only keep features with at TTF of at least 2, we go from 5949 features to 3230 features. What if we get more aggressive, and keep only features appearing in at least 2 documents? This means that they need to have a minimum document frequency of 2. (Of course, mathematically, this also implies they will have a minimum total term frequency of 2.)

# %%
min_docf = 2

cols_keep = np.where(docf >= min_docf)[0]
cols_keep
# Out:
# array([   3,    5,    6, ..., 5942, 5945, 5947], shape=(3201,))

# %% [markdown]
# Now we're down to 3201 features. What if we are even more aggressive: keep features that appear in at least two documents, and at least 4 times total in the corpus?

# %%
min_docf = 2
min_ttf = 4

cols_keep = np.where((docf >= min_docf) & (ttf >= min_ttf))[0]
cols_keep
# Out:
# array([   6,   11,   43, ..., 5942, 5945, 5947], shape=(1975,))

# %% [markdown]
# Now, we're left with 1975 features. Which features are we keeping?

# %%
vocabulary_trimmed = [vocabulary[x] for x in cols_keep]
vocabulary_trimmed
# Out:
# ['#americafirst',
#  '#apec2017',
#  '#cpac2018',
#  '#draintheswamp',
#  '#fake',
#  '#fakenews',
#  '#g20summit',
#  '#g7summit',
#  '#harvey',
#  '#hurricaneharvey',
#  '#icymi',
#  '#kateslaw',
#  '#lesm',
#  '#maga',
#  '#makeamericagreatagain',
#  '#memorialday',
#  '#ms13',
#  '#noko',
#  '#obamacare',
#  '#potusabroad',
#  '#prstrong',
#  '#puertorico',
#  '#repealandreplace',
#  '#righttotry',
#  '#taxday',
#  '#taxreform',
#  '#unga',
#  '#usa',
#  '#usaatunga',
#  '#uswomensopen',
#  '#weeklyaddress',
#  '#wef18',
#  '@abc',
#  '@abeshinzo',
#  '@cabinet',
#  '@charliekirk11',
#  '@cnn',
#  '@dhsgov',
#  '@donaldjtrumpjr',
#  '@donnawr8',
#  '@drudge_report',
#  '@emmanuelmacron',
#  '@erictrump',
#  '@fema',
#  '@flotus',
#  '@foxandfriends',
#  '@foxbusiness',
#  '@foxnews',
#  '@gop',
#  '@gopchairwoman',
#  '@gopleader',
#  '@govabbott',
#  '@ivankatrump',
#  '@jessebwatters',
#  '@judgejeanine',
#  '@justintrudeau',
#  '@kellyannepolls',
#  '@loudobbs',
#  '@mike_pence',
#  '@narendramodi',
#  '@nbcnews',
#  '@netanyahu',
#  '@nikkihaley',
#  '@nytimes',
#  '@pacificcommand',
#  '@paulsperry_',
#  '@potus',
#  '@presssec',
#  '@realdonaldtrump',
#  '@ricardorossello',
#  '@scavino45',
#  '@seanhannity',
#  '@senatemajldr',
#  '@speakerryan',
#  '@stevescalise',
#  '@team_trump45',
#  '@tuckercarlson',
#  '@un',
#  '@usga',
#  '@usnavy',
#  '@vp',
#  '@washingtonpost',
#  '@whitehouse',
#  'a.g',
#  'a.m',
#  'abandon',
#  'abc',
#  'abe',
#  'abl',
#  'absolut',
#  'abus',
#  'accept',
#  'access',
#  'accid',
#  'accomplish',
#  'accord',
#  'account',
#  'accur',
#  'accus',
#  'achiev',
#  'across',
#  'act',
#  'action',
#  'activ',
#  'actual',
#  'ad',
#  'adam',
#  'add',
#  'addict',
#  'addit',
#  'address',
#  'admin',
#  'administr',
#  'admir',
#  'admit',
#  'advantag',
#  'advic',
#  'advis',
#  'advisor',
#  'affect',
#  'afford',
#  'afghanistan',
#  'afternoon',
#  'age',
#  'agenc',
#  'agenda',
#  'agent',
#  'ago',
#  'agre',
#  'agreement',
#  'agricultur',
#  'ahead',
#  'air',
#  'airport',
#  'al',
#  'alabama',
#  'alaska',
#  'alert',
#  'alien',
#  'all-tim',
#  'alleg',
#  'alli',
#  'allow',
#  'almost',
#  'along',
#  'alreadi',
#  'also',
#  'aluminum',
#  'alway',
#  'amaz',
#  'amazon',
#  'amb',
#  'ambassador',
#  'amend',
#  'america',
#  'american',
#  'amnesti',
#  'among',
#  'amount',
#  'and/or',
#  'andrew',
#  'angela',
#  'anger',
#  'angri',
#  'anim',
#  'annapoli',
#  'anniversari',
#  'announc',
#  'annual',
#  'anoth',
#  'answer',
#  'anthem',
#  'anti-trump',
#  'anticip',
#  'anybodi',
#  'anymor',
#  'anyon',
#  'anyth',
#  'anyway',
#  'anywher',
#  'apolog',
#  'appl',
#  'appoint',
#  'appreci',
#  'apprentic',
#  'appropri',
#  'approv',
#  'approxim',
#  'april',
#  'arabia',
#  'area',
#  'arena',
#  'argentina',
#  'arizona',
#  'arm',
#  'armi',
#  'around',
#  'arrest',
#  'arriv',
#  'articl',
#  'asap',
#  'asia',
#  'ask',
#  'assad',
#  'assault',
#  'assist',
#  'associ',
#  'attack',
#  'attempt',
#  'attend',
#  'attorney',
#  'august',
#  'australia',
#  'author',
#  'automobil',
#  'award',
#  'away',
#  'b',
#  'back',
#  'background',
#  'bad',
#  'bail',
#  'baker',
#  'ballist',
#  'ban',
#  'barbara',
#  'barletta',
#  'barrier',
#  'base',
#  'battl',
#  'battlefield',
#  'beach',
#  'beat',
#  'beauti',
#  'becam',
#  'becom',
#  'bedminst',
#  'beg',
#  'begin',
#  'begun',
#  'behalf',
#  'behind',
#  'believ',
#  'benefit',
#  'berni',
#  'best',
#  'better',
#  'beyond',
#  'bias',
#  'big',
#  'bigger',
#  'biggest',
#  'bilater',
#  'bill',
#  'billi',
#  'billion',
#  'bipartisan',
#  'birthday',
#  'black',
#  'blame',
#  'bless',
#  'block',
#  'blumenth',
#  'board',
#  'bob',
#  'bold',
#  'bond',
#  'bonus',
#  'book',
#  'boom',
#  'border',
#  'boss',
#  'boston',
#  'boy',
#  'brave',
#  'braveri',
#  'break',
#  'breakup',
#  'brennan',
#  'brian',
#  'bridg',
#  'brief',
#  'bright',
#  'brilliant',
#  'bring',
#  'broke',
#  'broken',
#  'brother',
#  'brought',
#  'brown',
#  'budget',
#  'build',
#  'built',
#  'bump',
#  'burden',
#  'bush',
#  'busi',
#  'buy',
#  'cabinet',
#  'california',
#  'call',
#  'came',
#  'camp',
#  'campaign',
#  "can't",
#  'canada',
#  'cancel',
#  'candid',
#  'cannot',
#  'capit',
#  'car',
#  'caravan',
#  'care',
#  'career',
#  'carolina',
#  'carri',
#  'case',
#  'caucus',
#  'caught',
#  'caus',
#  'cbs',
#  'celebr',
#  'cemeteri',
#  'center',
#  'ceo',
#  'ceremoni',
#  'certain',
#  'chain',
#  'chairman',
#  'challeng',
#  'champion',
#  'championship',
#  'chanc',
#  'chancellor',
#  'chang',
#  'chao',
#  'charg',
#  'charlottesvill',
#  'cheat',
#  'check',
#  'chemic',
#  'cherish',
#  'chicago',
#  'chief',
#  'child',
#  'children',
#  'china',
#  'chines',
#  'choic',
#  'chris',
#  'christian',
#  'christma',
#  'christoph',
#  'chrysler',
#  'chuck',
#  'cia',
#  'circuit',
#  'cite',
#  'citi',
#  'citizen',
#  'civil',
#  'civilian',
#  'claim',
#  'clapper',
#  'class',
#  'classifi',
#  'clean',
#  'clear',
#  'clinton',
#  'clip',
#  'close',
#  'closer',
#  'clue',
#  'cnn',
#  'co',
#  'coal',
#  'coast',
#  'code',
#  'colleg',
#  'collud',
#  'collus',
#  'combat',
#  'come',
#  'comey',
#  'commander-in-chief',
#  'commerc',
#  'commiss',
#  'commit',
#  'committe',
#  'communic',
#  'communiti',
#  'compani',
#  'compar',
#  'competit',
#  'complain',
#  'complet',
#  'comprehens',
#  'comput',
#  'concern',
#  'conclus',
#  'condemn',
#  'condit',
#  'condol',
#  'conduct',
#  'confer',
#  'confid',
#  'confirm',
#  'conflict',
#  'confront',
#  'congrat',
#  'congratul',
#  'congress',
#  'congression',
#  'congressman',
#  'congresswoman',
#  'consid',
#  'conspiraci',
#  'constant',
#  'construct',
#  'consum',
#  'contact',
#  'continu',
#  'contribut',
#  'control',
#  'convers',
#  'convinc',
#  'cool',
#  'cooper',
#  'coordin',
#  'corker',
#  'corpor',
#  'correct',
#  'correspond',
#  'corrupt',
#  'cost',
#  'could',
#  'council',
#  'counsel',
#  'counti',
#  'countri',
#  'courag',
#  'cours',
#  'court',
#  'cover',
#  'coverag',
#  'coward',
#  'cox',
#  'cpac',
#  'crash',
#  'crazi',
#  'creat',
#  'credibl',
#  'credit',
#  'crew',
#  'cri',
#  'crime',
#  'crimea',
#  'crimin',
#  'crisi',
#  'critic',
#  'crook',
#  'cross',
#  'crowd',
#  'crumbl',
#  'cruz',
#  'cryin',
#  'cultur',
#  'cup',
#  'current',
#  'custom',
#  'cut',
#  'd.c',
#  'daca',
#  'dairi',
#  'dakota',
#  'dalla',
#  'damag',
#  'dan',
#  'danger',
#  'date',
#  'daughter',
#  'david',
#  'davo',
#  'day',
#  'de',
#  'dead',
#  'deal',
#  'dealt',
#  'death',
#  'debat',
#  'debbi',
#  'debt',
#  'decad',
#  'decemb',
#  'decid',
#  'decis',
#  'declar',
#  'dedic',
#  'deduct',
#  'deep',
#  'deepest',
#  'defeat',
#  'defend',
#  'defens',
#  'deficit',
#  'delay',
#  'deleg',
#  'delet',
#  'deliv',
#  'dem',
#  'demand',
#  'demean',
#  'democraci',
#  'democrat',
#  'denuclear',
#  'depart',
#  'dept',
#  'deputi',
#  'describ',
#  'deserv',
#  'desir',
#  'desper',
#  'despit',
#  'destini',
#  'destroy',
#  'destruct',
#  'detail',
#  'determin',
#  'deterr',
#  'devast',
#  'develop',
#  'die',
#  'diego',
#  'differ',
#  'difficult',
#  'dinner',
#  'direct',
#  'director',
#  'dirti',
#  'disappoint',
#  'disast',
#  'discredit',
#  'discuss',
#  'disgrac',
#  'disgust',
#  'dishonest',
#  'disparag',
#  'disrespect',
#  'disrupt',
#  'distort',
#  'district',
#  'divid',
#  'dnc',
#  'doctor',
#  'document',
#  'doj',
#  'dole',
#  'dollar',
#  'domin',
#  'donald',
#  'done',
#  'door',
#  'dossier',
#  'doubl',
#  'doubt',
#  'doug',
#  'dow',
#  'dr',
#  'drain',
#  'dream',
#  'drop',
#  'drug',
#  'duluth',
#  'dumb',
#  'durbin',
#  'duti',
#  'dynasti',
#  'e',
#  'e-mail',
#  'e.u',
#  'earli',
#  'earlier',
#  'easi',
#  'easili',
#  'east',
#  'easter',
#  'econom',
#  'economi',
#  'ed',
#  'educ',
#  'effect',
#  'effort',
#  'egypt',
#  'either',
#  'elect',
#  'elector',
#  'electr',
#  'els',
#  'email',
#  'embarrass',
#  'embassi',
#  'emerg',
#  'employ',
#  'employe',
#  'encourag',
#  'end',
#  'endors',
#  'endur',
#  'enemi',
#  'energi',
#  'enforc',
#  'engag',
#  'england',
#  'enjoy',
#  'enough',
#  'ensur',
#  'enter',
#  'enthusiasm',
#  'entir',
#  'epidem',
#  'equal',
#  'equip',
#  'era',
#  'eric',
#  'especi',
#  'est',
#  'establish',
#  'estim',
#  'etc',
#  'etern',
#  'europ',
#  'european',
#  'even',
#  'event',
#  'ever',
#  'everi',
#  'everybodi',
#  'everyon',
#  'everyth',
#  'evid',
#  'evil',
#  'exact',
#  'exampl',
#  'excel',
#  'except',
#  'excit',
#  'excus',
#  'execut',
#  'exist',
#  'exoner',
#  'expand',
#  'expect',
#  'expens',
#  'experi',
#  'expert',
#  'explain',
#  'expos',
#  'express',
#  'extend',
#  'extens',
#  'extraordinari',
#  'extrem',
#  'extremist',
#  'eye',
#  'f',
#  'fabric',
#  'face',
#  'facebook',
#  'facil',
#  'fact',
#  'factori',
#  'fail',
#  'failur',
#  'fair',
#  'faith',
#  'fake',
#  'fall',
#  'fals',
#  'famili',
#  'fan',
#  'fantast',
#  'far',
#  'farmer',
#  'fast',
#  'father',
#  'fault',
#  'favor',
#  'fbi',
#  'fear',
#  'februari',
#  'fed',
#  'feder',
#  'feel',
#  'fellow',
#  'felt',
#  'fema',
#  'fiction',
#  'field',
#  'fight',
#  'fighter',
#  'figur',
#  'file',
#  'filibust',
#  'fill',
#  'final',
#  'financi',
#  'find',
#  'fine',
#  'finest',
#  'finish',
#  'fire',
#  'firm',
#  'first',
#  'fisa',
#  'five',
#  'fix',
#  'flag',
#  'flake',
#  'flight',
#  'flood',
#  'florida',
#  'flow',
#  'flunki',
#  'flynn',
#  'focus',
#  'follow',
#  'food',
#  'fool',
#  'foolish',
#  'footbal',
#  'forc',
#  'ford',
#  'foreign',
#  'forev',
#  'forget',
#  'forgotten',
#  'form',
#  'former',
#  'fortun',
#  'forward',
#  'fought',
#  'found',
#  'foundat',
#  'four',
#  'fox',
#  'foxconn',
#  'franc',
#  'fraud',
#  'fraudul',
#  'free',
#  'freedom',
#  'friday',
#  'friend',
#  'friendship',
#  'front',
#  'fulfil',
#  'full',
#  'fulli',
#  'fun',
#  'fund',
#  'funni',
#  'futur',
#  'g',
#  'gain',
#  'game',
#  'gang',
#  'garbag',
#  'garden',
#  'gas',
#  'gather',
#  'gave',
#  'gdp',
#  'general',
#  'generat',
#  'georgia',
#  'germani',
#  'get',
#  'giant',
#  'gift',
#  'gillespi',
#  'gina',
#  'give',
#  'given',
#  'global',
#  'go',
#  'goal',
#  'god',
#  'goe',
#  'golf',
#  'gone',
#  'good',
#  'gop',
#  'gorsuch',
#  'got',
#  'gotten',
#  'gov',
#  'govern',
#  'governor',
#  'govt',
#  'graham',
#  'graham-cassidi',
#  'grant',
#  'grate',
#  'great',
#  'greater',
#  'greatest',
#  'greet',
#  'grid',
#  'grief',
#  'griev',
#  'ground',
#  'group',
#  'grow',
#  'growth',
#  'guam',
#  'guard',
#  'guess',
#  'gun',
#  'guy',
#  'h',
#  'hack',
#  'hand',
#  'handel',
#  'handl',
#  'hanniti',
#  'happen',
#  'happi',
#  'harbor',
#  'hard',
#  'hardwork',
#  'harley-davidson',
#  'harm',
#  'harri',
#  'harvard',
#  'harvey',
#  'haspel',
#  'hate',
#  'hater',
#  'hatr',
#  'head',
#  'health',
#  'healthcar',
#  'hear',
#  'heard',
#  'heart',
#  'heavi',
#  'heavili',
#  'heed',
#  'held',
#  'help',
#  'henc',
#  'henri',
#  'hero',
#  'heroic',
#  'hide',
#  'high',
#  'higher',
#  'highest',
#  'hill',
#  'hillari',
#  'hire',
#  'hispan',
#  'histor',
#  'histori',
#  'hit',
#  'hoax',
#  'hold',
#  'holiday',
#  'holocaust',
#  'home',
#  'homeland',
#  'honest',
#  'honor',
#  'hope',
#  'horribl',
#  'horrif',
#  'horror',
#  'hospit',
#  'host',
#  'hostag',
#  'hour',
#  'hous',
#  'houston',
#  'ht',
#  'https',
#  'huge',
#  'human',
#  'hundr',
#  'hunt',
#  'hurrican',
#  'hurt',
#  'ice',
#  'idea',
#  'ig',
#  'illeg',
#  'imagin',
#  'immedi',
#  'immigr',
#  'impact',
#  'implod',
#  'import',
#  'impos',
#  'imposs',
#  'impress',
#  'improv',
#  'inaccur',
#  'inaugur',
#  'includ',
#  'incom',
#  'incompet',
#  'incorrect',
#  'increas',
#  'incred',
#  'independ',
#  'index',
#  'india',
#  'indiana',
#  'individu',
#  'industri',
#  'ineffect',
#  'infest',
#  'infiltr',
#  'inflow',
#  'influenc',
#  'info',
#  'inform',
#  'infrastructur',
#  'initi',
#  'injur',
#  'innoc',
#  'innov',
#  'inspector',
#  'inspir',
#  'instead',
#  'instruct',
#  'insur',
#  'intel',
#  'intellectu',
#  'intellig',
#  'intent',
#  'interest',
#  'intern',
#  'internet',
#  'interview',
#  'invest',
#  'investig',
#  'invit',
#  'involv',
#  'iowa',
#  'iran',
#  'iranian',
#  'iraq',
#  'irma',
#  'isi',
#  'islam',
#  'island',
#  'israel',
#  'issu',
#  'itali',
#  'ivanka',
#  'j',
#  'jackson',
#  'jail',
#  'jame',
#  'januari',
#  'japan',
#  'japanes',
#  'jeff',
#  'jerri',
#  'jersey',
#  'jerusalem',
#  'jim',
#  'jinp',
#  'job',
#  'jobless',
#  'joe',
#  'john',
#  'johnson',
#  'join',
#  'joint',
#  'joke',
#  'jon',
#  'jone',
#  'jong',
#  'jong-un',
#  'jordan',
#  'journal',
#  'journey',
#  'jr',
#  'juan',
#  'judg',
#  'judici',
#  'june',
#  'justic',
#  'justin',
#  'kansa',
#  'karen',
#  'kate',
#  'kati',
#  'keep',
#  ...]

# %% [markdown]
# Now, let's actually trim the DFM:

# %%
dfm_trimmed = dfm_sparse[:, cols_keep]
dfm_trimmed.shape
# Out:
# (3866, 1975)

# %% [markdown]
# ### TF-IDF weighting
#
# A more common (and less simple) approach to weighting is to use the TF-IDF weighting procedure. There are many variations of the weighting procedure, but here we'll calculate one variation by hand (using the lecture formula). Then we'll use an "out of the box" function available in the `sklearn` module.
#
# For the manual calculation, we first calculate the inverse document frequency for each term (IDF):

# %%
idf = np.log(dfm_sparse.shape[0]/docf)
idf
# Out:
# array([8.25997566, 8.25997566, 8.25997566, ..., 8.25997566, 6.8736813 ,
#        8.25997566], shape=(5949,))

# %% [markdown]
# Next, we multiply each value in the DFM by its feature's IDF:

# %%
dfm_tfidf = dfm_sparse.multiply(idf).tocsr()
print(dfm_tfidf)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 50274 stored elements and shape (3866, 5949)>
#   Coords	Values
#   (0, 96)	7.566828479208331
#   (0, 151)	3.916170237914592
#   (0, 883)	2.922437580066958
#   (0, 1200)	5.081921829420331
#   (0, 2533)	3.853256412504023
#   (0, 3470)	3.0725898539275214
#   (0, 3544)	2.8572982778959966
#   (0, 4404)	5.315536680601836
#   (0, 5424)	3.78263884529007
#   (0, 5876)	3.8291588609249625
#   (0, 5881)	2.826253656214037
#   (1, 96)	7.566828479208331
#   (1, 209)	8.259975659768276
#   (1, 381)	7.161363371100166
#   (1, 660)	8.259975659768276
#   (1, 881)	2.7669142164277276
#   (1, 1130)	5.215453222044853
#   (1, 2943)	6.650537747334176
#   (1, 3881)	4.676456721312166
#   (1, 4732)	2.2221047398461384
#   (2, 590)	3.58714682530637
#   (2, 595)	7.161363371100166
#   (2, 881)	2.7669142164277276
#   (2, 1200)	5.081921829420331
#   (2, 2533)	3.853256412504023
#   :	:
#   (3864, 2922)	6.8736812986483855
#   (3864, 3570)	6.650537747334176
#   (3864, 3833)	3.0396198346899514
#   (3864, 3880)	8.259975659768276
#   (3864, 4236)	4.0855883898726395
#   (3864, 4940)	7.566828479208331
#   (3864, 4941)	5.081921829420331
#   (3864, 5422)	2.680245833782054
#   (3864, 5436)	4.927771149593072
#   (3864, 5764)	3.0781921094761913
#   (3864, 5925)	4.199532649221857
#   (3865, 261)	7.161363371100166
#   (3865, 746)	6.314065510712963
#   (3865, 1226)	6.062751082432057
#   (3865, 1681)	6.650537747334176
#   (3865, 1802)	3.203729854419968
#   (3865, 3691)	4.388774648860386
#   (3865, 3752)	4.4987755440747135
#   (3865, 4153)	4.270991613204002
#   (3865, 4470)	4.858778278106121
#   (3865, 4514)	5.264243386214285
#   (3865, 4641)	7.566828479208331
#   (3865, 4985)	6.314065510712963
#   (3865, 5315)	2.8132382881019664
#   (3865, 5882)	4.388774648860386

# %% [markdown]
# There are variations of TF-IDF weighting that attempt to deal with various technical issues, which we covered in lecture. For example, it is common to use "smoothed" inverse document frequency in many applications. It is straight forward to calculate:

# %%
sidf = np.log((1+dfm_sparse.shape[0])/(1+docf))+1
sidf
# Out:
# array([8.56708711, 8.56708711, 8.56708711, ..., 8.56708711, 7.65079638,
#        8.56708711], shape=(5949,))

# %% [markdown]
# Now, let's weight the DFM using tf-idf where idf is "smoothed":

# %%
dfm_tfidf_sm = dfm_sparse.multiply(sidf).tocsr()
print(dfm_tfidf_sm)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 50274 stored elements and shape (3866, 5949)>
#   Coords	Values
#   (0, 96)	8.161622002939186
#   (0, 151)	4.903525464917705
#   (0, 883)	3.917900039642486
#   (0, 1200)	6.041358466739096
#   (0, 2533)	4.841393683810699
#   (0, 3470)	4.067277440717087
#   (0, 3544)	3.853062520147178
#   (0, 4404)	6.264502018053306
#   (0, 5424)	4.771597921875157
#   (0, 5876)	4.81758303511698
#   (0, 5881)	3.822154982684102
#   (1, 96)	8.161622002939186
#   (1, 209)	8.567087111047352
#   (1, 381)	7.873939930487406
#   (1, 660)	8.567087111047352
#   (1, 881)	3.7630660663140953
#   (1, 1130)	6.169191838248981
#   (1, 2943)	7.468474822379242
#   (1, 3881)	5.649316378963072
#   (1, 4732)	3.219979580329883
#   (2, 590)	4.578103064483077
#   (2, 595)	7.873939930487406
#   (2, 881)	3.7630660663140953
#   (2, 1200)	6.041358466739096
#   (2, 2533)	4.841393683810699
#   :	:
#   (3864, 2922)	7.6507963791731965
#   (3864, 3570)	7.468474822379242
#   (3864, 3833)	4.034487617894095
#   (3864, 3880)	8.567087111047352
#   (3864, 4236)	5.070579549580872
#   (3864, 4940)	8.161622002939186
#   (3864, 4941)	6.041358466739096
#   (3864, 5422)	3.676737982825598
#   (3864, 5436)	5.892938461620823
#   (3864, 5764)	4.072848485766542
#   (3864, 5925)	5.182696847701577
#   (3865, 261)	7.873939930487406
#   (3865, 746)	7.180792749927461
#   (3865, 1226)	6.957649198613251
#   (3865, 1681)	7.468474822379242
#   (3865, 1802)	4.19763925858033
#   (3865, 3691)	5.36841399349667
#   (3865, 3752)	5.476044657689036
#   (3865, 4153)	5.252901106374826
#   (3865, 4470)	5.826247087122151
#   (3865, 4514)	6.2157118538838745
#   (3865, 4641)	8.161622002939186
#   (3865, 4985)	7.180792749927461
#   (3865, 5315)	3.8091958380415964
#   (3865, 5882)	5.36841399349667

# %% [markdown]
# Fortunately, the `sklearn` module has a `TfidfTransformer` class that allows you to perform tf-idf weighting on a DFM you already have as a sparse matrix. Note that this process yields tf-idf weighting with smoothed idf.

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# Step 1: initialise a `TfidfTransformer` object
# Note: we will not normalise, so select norm=None
transformer = TfidfTransformer(norm=None)
# Step 2: perform the tf-idf weighting on the sparse DFM
dfm_tfidf = transformer.fit_transform(dfm_sparse)

# %% [markdown]
# You can see that the values reported are the same as those we calculated by hand above.

# %%
print(dfm_tfidf)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 50274 stored elements and shape (3866, 5949)>
#   Coords	Values
#   (0, 96)	8.161622002939186
#   (0, 151)	4.903525464917705
#   (0, 883)	3.917900039642486
#   (0, 1200)	6.041358466739096
#   (0, 2533)	4.841393683810699
#   (0, 3470)	4.067277440717087
#   (0, 3544)	3.853062520147178
#   (0, 4404)	6.264502018053306
#   (0, 5424)	4.771597921875157
#   (0, 5876)	4.81758303511698
#   (0, 5881)	3.822154982684102
#   (1, 96)	8.161622002939186
#   (1, 209)	8.567087111047352
#   (1, 381)	7.873939930487406
#   (1, 660)	8.567087111047352
#   (1, 881)	3.7630660663140953
#   (1, 1130)	6.169191838248981
#   (1, 2943)	7.468474822379242
#   (1, 3881)	5.649316378963072
#   (1, 4732)	3.219979580329883
#   (2, 590)	4.578103064483077
#   (2, 595)	7.873939930487406
#   (2, 881)	3.7630660663140953
#   (2, 1200)	6.041358466739096
#   (2, 2533)	4.841393683810699
#   :	:
#   (3864, 2922)	7.6507963791731965
#   (3864, 3570)	7.468474822379242
#   (3864, 3833)	4.034487617894095
#   (3864, 3880)	8.567087111047352
#   (3864, 4236)	5.070579549580872
#   (3864, 4940)	8.161622002939186
#   (3864, 4941)	6.041358466739096
#   (3864, 5422)	3.676737982825598
#   (3864, 5436)	5.892938461620823
#   (3864, 5764)	4.072848485766542
#   (3864, 5925)	5.182696847701577
#   (3865, 261)	7.873939930487406
#   (3865, 746)	7.180792749927461
#   (3865, 1226)	6.957649198613251
#   (3865, 1681)	7.468474822379242
#   (3865, 1802)	4.19763925858033
#   (3865, 3691)	5.36841399349667
#   (3865, 3752)	5.476044657689036
#   (3865, 4153)	5.252901106374826
#   (3865, 4470)	5.826247087122151
#   (3865, 4514)	6.2157118538838745
#   (3865, 4641)	8.161622002939186
#   (3865, 4985)	7.180792749927461
#   (3865, 5315)	3.8091958380415964
#   (3865, 5882)	5.36841399349667

# %% [markdown]
# Finally, let's see if re-weighting the DFM using tf-idf changes which words are considered the (weighted) top words. We'll do this by plotting a word cloud.

# %%
top_features2 = dfm_tfidf.sum(axis = 0).A1
top_features2 = pd.Series(top_features2, index=vocabulary).astype(int)

wc = wordcloud.WordCloud(width=800,
                         height=400,
                         background_color="white",
                         relative_scaling = 1,
                         max_words=200, 
                         random_state=42)

wc = wc.generate_from_frequencies(top_features2)

wc = wc.recolor(color_func=lambda *args, **kwargs: (51,51,255))

plt.figure(figsize=(8, 4))
plt.imshow(wc)
plt.axis("off")
plt.subplots_adjust(left=0, right=1, top=1, bottom=0)
plt.show()
